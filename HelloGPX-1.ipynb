# %% [markdown]
# # Hello GPX File

# %%
import sys
# !{sys.executable} -m pip install gpxpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 111 kB 8.0 MB/s
# ...
#   Created wheel for gpxpy: filename=gpxpy-1.5.0-py3-none-any.whl size=42898 sha256=11561fa54cd85fb4ac82d5bb6ee58588be04a73139c5fa63d9e44e272e05aa43
#   Stored in directory: /root/.cache/pip/wheels/78/49/b6/d1851fcb4ee10fa784325d7fcf6c97789157c706ab3a71e2b6
# Successfully built gpxpy
# ...

# %%
import gpxpy
import gpxpy.gpx

gpx_file = open('3_Zinnenlauf_.gpx', 'r')
gpx = gpxpy.parse(gpx_file)
