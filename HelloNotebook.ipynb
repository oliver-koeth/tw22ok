# %% [markdown]
# # Hello Notebook World

# %%
import matplotlib.pyplot as plt

plt.plot([72,26,22,40,58,70])
plt.ylabel('My COVID HRV')
plt.xlabel('Days after first symptoms')

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
